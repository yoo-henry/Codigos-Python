# %%
while True:
    pergunta = (input("Qual o número de telefone da sua chush ?"))
    if pergunta == "987177074":
        print("acertou!!")
        break
    else:
        print("sai daqui")

# %%
while True:
    pergunta = int(input("Qual é o seu número intiro ?"))
    if pergunta == 987177074:
        print("Ganhou 100zin")
        break
    else:
        print("número errado, tente novamente")
