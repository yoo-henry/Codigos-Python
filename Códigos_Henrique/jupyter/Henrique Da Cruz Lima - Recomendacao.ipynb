# %% [markdown]
# ### Recomendação de Filmes
#
# Você vai criar um sistema de recomendação de filmes que pergunta ao usuário:
#
# Qual gênero de filme ele prefere (Ação, Comédia ou Terror).
#
# Como está seu humor hoje (Feliz, Neutro ou Estressado).
#
# Com base nessas respostas, o programa deve recomendar um filme diferente usando estruturas condicionais (if, elif, else).
#
# Regras de Recomendação:
#
# ![image.png](attachment:image.png)
#
#
# Requisitos do Código:
# O programa deve perguntar o gênero e o humor.
#
# Se o usuário digitar uma opção inválida, o programa deve dizer: "Opção inválida, tente novamente!" e encerrar.
#
# Use if, elif e else para decidir qual filme recomendar.
#
# No final, mostre a recomendação em uma mensagem como:
#
# "Com base no seu gênero preferido (Ação) e humor (Estressado), recomendamos: Duro de Matar!"

# %%
genero_filme = input("Qual o gênero de filme você prefere? (Ação, Comédia ou Terror) ").capitalize()
humor = input("Como está seu humor hoje ? (Feliz, Neutro ou Estressado)").capitalize()
# .capitalize() faz com que a primeira letra maiuscula e o resto minusculo funcione 

if genero_filme == "Ação" and humor == "Feliz":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'Homem-Aranha'")
elif genero_filme == "Ação" and humor == "Neutro":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'John Wick'")
elif genero_filme == "Ação" and humor == "Estressado":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'Duro de Matar'")
elif genero_filme == "Comédia" and humor == "Feliz":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'Superbad'")
elif genero_filme == "Comédia" and humor == "Neutro":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'Escola de Rock'")
elif genero_filme == "Comédia" and humor == "Estressado":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'Se beber,Não Case'")
elif genero_filme == "Terro" and humor == "Feliz":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'A Noite do Terror'" )
elif genero_filme == "Terror" and humor == "Neutro":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'Invocação do Mal'")
elif genero_filme == "Terror" and humor == "Estressado":
    print(f"Com base no seu gosto a {genero_filme} e o {humor} de recomendo 'O iluminado'")
else:
    print("Opção inválida,tente novamente!")
# Out:
# Com base no seu Ação e o Feliz de recomendo 'Homem-Aranha'

# %% [markdown]
# ### Recomenda Jogo
#
# Você vai criar um sistema de recomendação de jogos que pergunta ao usuário:
#
# Qual gênero de jogo ele mais gosta (FPS, RPG, Esportes ou Battle Royale).
#
# Quanto tempo ele tem para jogar (Curto: 1h, Médio: 2-3h, Longo: 4h+).
#
# Com base nessas respostas, o programa deve recomendar um jogo usando estruturas condicionais (if, elif, else).
#
# Regras de Recomendação:
#
# ![image.png](attachment:image.png)
#
# Se o usuário digitar uma opção inválida, o programa deve dizer: "Opção inválida, tente novamente!" e encerrar.
#
# Use if, elif e else para decidir qual jogo recomendar.
#
# No final, mostre a recomendação em uma mensagem como:
#
# "Baseado no seu gênero favorito (RPG) e tempo disponível (Longo), recomendamos: Elden Ring!"
#
# Exemplo de Saída:
# === Escolha o Seu Próximo Jogo ===
# Qual seu gênero de jogo favorito? (FPS, RPG, Esportes, Battle Royale): RPG
# Quanto tempo você tem para jogar? (Curto, Médio, Longo): Longo
#
# Baseado no seu gênero favorito (RPG) e tempo disponível (Longo), recomendamos: Elden Ring!
# Dicas:
# Use .lower() ou .upper() para evitar erros de digitação (ex: "rpg" ou "RPG").
#
# Verifique se as entradas são válidas antes de recomendar.
#
# Você pode adicionar uma mensagem extra como: "Bom jogo! 🎮🔥" no final.

# %%
print("=======Escolha seu próximo jogo=======")
genero_jogo = input("Qual o gênero de jogo você prefere? (FPS,RPG,Esportes,Battle Royale) ").lower()
tempo_jogo = input("Qual serua o tempo que vc quer jogar ? ( Curto (1h) Médio(2-3h) Longo(4h+) )").lower

if genero_jogo == "fps" and tempo_jogo == "curto":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'Valorant'")
elif genero_jogo == "fps" and tempo_jogo == "médio":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'Call of Duty: Warzone'")
elif genero_jogo == "fps" and tempo_jogo == "longo":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'Counter-Striker 2'")
elif genero_jogo == "rpg" and tempo_jogo == "curto":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'Stardew Valley'")
elif genero_jogo == "rpg" and tempo_jogo == "médio":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'The Witcher 3'")
elif genero_jogo == "rpg" and tempo_jogo == "longo":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'Elden Ring'")
elif genero_jogo == "esportes" and tempo_jogo == "curto":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'Rocket League'")
elif genero_jogo == "esportes" and tempo_jogo == "médio":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'FIFA 24'")
elif genero_jogo == "esportes" and tempo_jogo == "longo":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'NBA 2K24'")
elif genero_jogo == "battle royale" and tempo_jogo == "curto":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'Fortinite'")
elif genero_jogo == "battle royale" and tempo_jogo == "médio":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'Apex Legends'")
elif genero_jogo == "battle royale" and tempo_jogo == "longo":
    print(f"Com base no seu gosto a {genero_jogo} e o tempo {tempo_jogo} de recomendo 'PUBG:Battlegrounds'")
else:
    print("Opção inválida,tente novamente!")
# Out:
# =======Escolha seu próximo jogo=======
# Opção inválida,tente novamente!
